# %%
import pandas as pd
from PIL import Image

# Load the dataset
data_path = '/app/data.csv'
data = pd.read_csv(data_path)

# Load the image
image_path = '/app/image.png'
image = Image.open(image_path)
image.show()

# Perform the sum operation
total_sum = data['value'].sum()
print(f'The sum of all values is: {total_sum}')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1022x1022>
# The sum of all values is: 37
